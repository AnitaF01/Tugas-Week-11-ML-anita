# %%
import pandas as pd #untuk manipulasi dan analisis data.
import numpy as np #untuk komputasi numerik dengan array dan matriks.
import torch #untuk membangun dan melatih model neural network.
import torch.nn as nn #Modul PyTorch yang berisi berbagai lapisan dan fungsi untuk membangun neural network.
import torch.optim as optim #Modul PyTorch yang berisi berbagai algoritma optimasi untuk melatih model neural network.
from torch.utils.data import DataLoader, TensorDataset #untuk membuat dan mengelola dataset, serta memuat data secara efisien selama pelatihan.
from sklearn.datasets import make_classification #untuk membuat dataset sintetis, seperti dataset klasifikasi.
from sklearn.model_selection import train_test_split #untuk membagi dataset menjadi data latih dan data uji.
from sklearn.preprocessing import StandardScaler #untuk melakukan preprocessing data, seperti standarisasi fitur.
from sklearn.metrics import accuracy_score #untuk menghitung akurasi model klasifikasi.

# %%
X, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=42)
#membuat data dummy untuk klasifikasi data

scaler = StandardScaler()
X = scaler.fit_transform(X)
#pemrosesan data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#membagi data menjadi data latih dan data uji

# %%
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)
#mengonversi data ke tensors PyTorch

# %%
def create_mlp(input_size, hidden_layers, hidden_neurons, activation_function):
    layers = []
    layers.append(nn.Linear(input_size, hidden_neurons))
    for _ in range(hidden_layers - 1):
        layers.append(nn.Linear(hidden_neurons, hidden_neurons))
    #menambahkan lapisan tersembunyi

    if activation_function == 'linear':
        activation = nn.Identity()
    elif activation_function == 'Sigmoid':
        activation = nn.Sigmoid()
    elif activation_function == 'ReLU':
        activation = nn.ReLU()
    elif activation_function == 'Softmax':
        activation = nn.Softmax(dim=1)
    elif activation_function == 'Tanh':
        activation = nn.Tanh()
    #memilih fungsi aktivasi

    layers.append(nn.Linear(hidden_neurons, 2))

    model = nn.Sequential(*layers)
    return model
    #mnggabungkan semua lapisan


#menentukan model MLP

# %%
def train_and_evaluate(model, X_train_tensor, y_train_tensor, X_test_tensor, y_test_tensor, batch_size, epochs, learning_rate):
    train_data = TensorDataset(X_train_tensor, y_train_tensor)
    train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)

    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.CrossEntropyLoss()

    model.train()
    for epoch in range(epochs):
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            output = model(X_batch)
            loss = criterion(output, y_batch)
            loss.backward()
            optimizer.step()
    #mengatur model ke mode pelatihan

    model.eval()
    with torch.no_grad():
        train_output = model(X_train_tensor)
        train_pred = torch.argmax(train_output, dim=1)
        train_accuracy = accuracy_score(y_train_tensor.numpy(), train_pred.numpy())
        train_loss = criterion(train_output, y_train_tensor).item()
        #akurasi pelatihan

        test_output = model(X_test_tensor)
        test_pred = torch.argmax(test_output, dim=1)
        test_accuracy = accuracy_score(y_test_tensor.numpy(), test_pred.numpy())
        test_loss = criterion(test_output, y_test_tensor).item()
        #akurasi pengujian
        #mengatur model ke mode evaluasi

    return train_accuracy, train_loss, test_accuracy, test_loss
     #mengembalikan hasil

#melatih dan mengevaluasi model

# %%
hidden_layers_options = [1, 2, 3]
hidden_neurons_options = [4, 8, 16, 32, 64]
activation_functions = ['linear', 'Sigmoid', 'ReLU', 'Softmax', 'Tanh']
epochs_options = [25, 50, 100, 250]
learning_rates = [0.1, 0.01, 0.001, 0.0001]
batch_sizes = [64, 128, 256, 512]
#eksperimen menggunakan hyperparameter

results = []
best_result = None
worst_result = None
best_per_activation = {activation: None for activation in activation_functions}
#melacak hasil eksperimen

for hidden_layers in hidden_layers_options:
    for hidden_neurons in hidden_neurons_options:
        for activation_function in activation_functions:
            for epochs in epochs_options:
                for learning_rate in learning_rates:
                    for batch_size in batch_sizes:
                        print(f"Melatih dengan {hidden_layers} lapisan tersembunyi, {hidden_neurons} neuron, fungsi aktivasi {activation_function}, "
                              f"{epochs} epoch, tingkat pembelajaran {learning_rate}, ukuran batch {batch_size}")
                        #mencetak konfigurasi eksperimen saat ini

                        model = create_mlp(X_train_tensor.shape[1], hidden_layers, hidden_neurons, activation_function)
                        #membuat model untuk setiap kombinasi hyperparameter

                        train_acc, train_loss, test_acc, test_loss = train_and_evaluate(
                            model, X_train_tensor, y_train_tensor, X_test_tensor, y_test_tensor, batch_size, epochs, learning_rate
                        )
                        #melatih dan mengevaluasi model

                        results.append({
                            'Hidden Layers': hidden_layers,
                            'Hidden Neurons': hidden_neurons,
                            'Activation Function': activation_function,
                            'Epochs': epochs,
                            'Learning Rate': learning_rate,
                            'Batch Size': batch_size,
                            'Train Accuracy': train_acc,
                            'Train Loss': train_loss,
                            'Test Accuracy': test_acc,
                            'Test Loss': test_loss
                        })
                        #menyimpan hasil

                        print(f"Akurasi Pelatihan: {train_acc * 100:.2f}%")
                        print(f"Loss Pelatihan: {train_loss:.4f}")
                        print(f"Akurasi Pengujian: {test_acc * 100:.2f}%")
                        print(f"Loss Pengujian: {test_loss:.4f}\n")
                        #mencetak hasil akhir dari eksperimen ini


                        if best_result is None or test_acc > best_result['Test Accuracy']:
                            best_result = {
                                'Hyperparameters': {
                                    'Hidden Layers': hidden_layers,
                                    'Hidden Neurons': hidden_neurons,
                                    'Activation Function': activation_function,
                                    'Epochs': epochs,
                                    'Learning Rate': learning_rate,
                                    'Batch Size': batch_size
                                },
                                'Test Accuracy': test_acc
                            }
                        if worst_result is None or test_acc < worst_result['Test Accuracy']:
                            worst_result = {
                                'Hyperparameters': {
                                    'Hidden Layers': hidden_layers,
                                    'Hidden Neurons': hidden_neurons,
                                    'Activation Function': activation_function,
                                    'Epochs': epochs,
                                    'Learning Rate': learning_rate,
                                    'Batch Size': batch_size
                                },
                                'Test Accuracy': test_acc
                            }
                         #memperbarui hasil terbaik dan terburuk

                        if best_per_activation[activation_function] is None or test_acc > best_per_activation[activation_function]['Test Accuracy']:
                            best_per_activation[activation_function] = {
                                'Hyperparameters': {
                                    'Hidden Layers': hidden_layers,
                                    'Hidden Neurons': hidden_neurons,
                                    'Activation Function': activation_function,
                                    'Epochs': epochs,
                                    'Learning Rate': learning_rate,
                                    'Batch Size': batch_size
                                },
                                'Test Accuracy': test_acc
                            }
                          #melacak konfigurasi terbaik untuk setiap fungsi aktivasi

#loop melalui semua kombinasi hyperparameter
# Out:
# Streaming output truncated to the last 5000 lines.
# Loss Pengujian: 0.3784
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Sigmoid, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 88.00%
# Loss Pelatihan: 0.3613
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.4025
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 88.00%
# Loss Pelatihan: 0.3137
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.4017
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3115
# Akurasi Pengujian: 86.00%
# Loss Pengujian: 0.3728
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3105
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3964
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3107
# Akurasi Pengujian: 84.00%
# Loss Pengujian: 0.3908
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3077
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3822
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3084
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3797
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3076
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3839
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 89.00%
# Loss Pelatihan: 0.3097
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3922
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3823
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3085
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3869
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3165
# Akurasi Pengujian: 86.00%
# Loss Pengujian: 0.3764
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3534
# Akurasi Pengujian: 84.00%
# Loss Pengujian: 0.3984
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 80.57%
# Loss Pelatihan: 0.5459
# Akurasi Pengujian: 77.67%
# Loss Pengujian: 0.5673
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 62.43%
# Loss Pelatihan: 0.6748
# Akurasi Pengujian: 62.67%
# Loss Pengujian: 0.6776
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 51.86%
# Loss Pelatihan: 0.6994
# Akurasi Pengujian: 49.00%
# Loss Pengujian: 0.7141
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 57.71%
# Loss Pelatihan: 0.6816
# Akurasi Pengujian: 59.67%
# Loss Pengujian: 0.6795
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3215
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3982
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3086
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3896
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 89.00%
# Loss Pelatihan: 0.3124
# Akurasi Pengujian: 84.00%
# Loss Pengujian: 0.3746
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 89.00%
# Loss Pelatihan: 0.3130
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3891
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3078
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3777
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3088
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3889
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3072
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3826
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3099
# Akurasi Pengujian: 86.00%
# Loss Pengujian: 0.3897
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3792
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3809
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3819
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3073
# Akurasi Pengujian: 86.00%
# Loss Pengujian: 0.3829
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 87.71%
# Loss Pelatihan: 0.3584
# Akurasi Pengujian: 84.00%
# Loss Pengujian: 0.4059
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 82.71%
# Loss Pelatihan: 0.5287
# Akurasi Pengujian: 77.00%
# Loss Pengujian: 0.5492
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 75.86%
# Loss Pelatihan: 0.5764
# Akurasi Pengujian: 69.67%
# Loss Pengujian: 0.5924
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 78.43%
# Loss Pelatihan: 0.6225
# Akurasi Pengujian: 76.00%
# Loss Pengujian: 0.6218
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3127
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3780
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3085
# Akurasi Pengujian: 84.00%
# Loss Pengujian: 0.3805
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3096
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3898
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3206
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.4171
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3075
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3769
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3077
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3824
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3071
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3801
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 88.00%
# Loss Pelatihan: 0.3084
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3884
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3834
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3073
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3842
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3069
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3805
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3075
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3816
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3085
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3798
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 86.71%
# Loss Pelatihan: 0.3755
# Akurasi Pengujian: 83.00%
# Loss Pengujian: 0.4231
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 80.43%
# Loss Pelatihan: 0.5491
# Akurasi Pengujian: 78.00%
# Loss Pengujian: 0.5645
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 83.00%
# Loss Pelatihan: 0.5845
# Akurasi Pengujian: 79.67%
# Loss Pengujian: 0.5975
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 250 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 88.00%
# Loss Pelatihan: 0.3088
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3883
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 250 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 87.29%
# Loss Pelatihan: 0.3234
# Akurasi Pengujian: 83.67%
# Loss Pengujian: 0.4136
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 250 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 83.71%
# Loss Pelatihan: 3.4555
# Akurasi Pengujian: 82.33%
# Loss Pengujian: 4.2970
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 250 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3255
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.4316
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 250 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3082
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3762
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 250 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3082
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3908
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 250 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3073
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3786
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 250 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3087
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3802
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3072
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3843
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3071
# Akurasi Pengujian: 84.00%
# Loss Pengujian: 0.3814
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3812
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3071
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3839
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3069
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3812
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3814
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3110
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3759
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi ReLU, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3491
# Akurasi Pengujian: 84.00%
# Loss Pengujian: 0.3992
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 83.00%
# Loss Pelatihan: 0.4270
# Akurasi Pengujian: 81.67%
# Loss Pengujian: 0.4449
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3381
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.4265
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3128
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3873
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 86.86%
# Loss Pelatihan: 0.3365
# Akurasi Pengujian: 81.33%
# Loss Pengujian: 0.3991
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3098
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3911
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 87.86%
# Loss Pelatihan: 0.3081
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3889
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3080
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3759
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3084
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3801
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3071
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3825
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3072
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3825
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3291
# Akurasi Pengujian: 84.00%
# Loss Pengujian: 0.3956
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 86.14%
# Loss Pelatihan: 0.4032
# Akurasi Pengujian: 83.00%
# Loss Pengujian: 0.4485
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 78.57%
# Loss Pelatihan: 0.5216
# Akurasi Pengujian: 73.33%
# Loss Pengujian: 0.5446
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 78.57%
# Loss Pelatihan: 0.6000
# Akurasi Pengujian: 74.33%
# Loss Pengujian: 0.6088
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 54.71%
# Loss Pelatihan: 0.6877
# Akurasi Pengujian: 52.00%
# Loss Pengujian: 0.6925
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 73.14%
# Loss Pelatihan: 0.6511
# Akurasi Pengujian: 73.33%
# Loss Pengujian: 0.6439
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3127
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3747
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3104
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3899
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3128
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3981
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3132
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3719
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3075
# Akurasi Pengujian: 86.33%
# Loss Pengujian: 0.3798
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 89.29%
# Loss Pelatihan: 0.3091
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3806
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 89.00%
# Loss Pelatihan: 0.3075
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3805
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3090
# Akurasi Pengujian: 84.00%
# Loss Pengujian: 0.3881
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3810
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3071
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3823
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3802
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3076
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3832
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 87.14%
# Loss Pelatihan: 0.3596
# Akurasi Pengujian: 82.33%
# Loss Pengujian: 0.4126
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 77.86%
# Loss Pelatihan: 0.5644
# Akurasi Pengujian: 75.00%
# Loss Pengujian: 0.5711
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 77.57%
# Loss Pelatihan: 0.6138
# Akurasi Pengujian: 78.00%
# Loss Pengujian: 0.6211
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 51.29%
# Loss Pelatihan: 0.6632
# Akurasi Pengujian: 54.33%
# Loss Pengujian: 0.6609
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3118
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3779
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 87.86%
# Loss Pelatihan: 0.3465
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.4027
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3075
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3824
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3123
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3750
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3074
# Akurasi Pengujian: 84.00%
# Loss Pengujian: 0.3833
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 89.14%
# Loss Pelatihan: 0.3082
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3885
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3072
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3827
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3083
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3818
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3803
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.00%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3803
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3821
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3073
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3805
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3105
# Akurasi Pengujian: 86.00%
# Loss Pengujian: 0.3814
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3462
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.4018
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 84.71%
# Loss Pelatihan: 0.4466
# Akurasi Pengujian: 78.00%
# Loss Pengujian: 0.4774
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 83.86%
# Loss Pelatihan: 0.5608
# Akurasi Pengujian: 80.00%
# Loss Pengujian: 0.5769
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3106
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3839
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3113
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3741
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 88.00%
# Loss Pelatihan: 0.3076
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3791
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3081
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3836
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3072
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3836
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3081
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3809
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3072
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3842
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3092
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3754
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.00%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3806
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3071
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3784
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3806
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3074
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3820
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3069
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3811
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3071
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3818
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3116
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3743
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 89.14%
# Loss Pelatihan: 0.3647
# Akurasi Pengujian: 84.00%
# Loss Pengujian: 0.4041
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 88.00%
# Loss Pelatihan: 0.3144
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3935
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3160
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3985
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3137
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3973
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 87.57%
# Loss Pelatihan: 0.3209
# Akurasi Pengujian: 83.33%
# Loss Pengujian: 0.4207
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3081
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3870
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3077
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3792
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3077
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3786
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3095
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3840
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3071
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3809
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3072
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3824
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3096
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3816
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 85.29%
# Loss Pelatihan: 0.4521
# Akurasi Pengujian: 80.00%
# Loss Pengujian: 0.4769
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 81.29%
# Loss Pelatihan: 0.5242
# Akurasi Pengujian: 78.67%
# Loss Pengujian: 0.5350
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 49.57%
# Loss Pelatihan: 0.6926
# Akurasi Pengujian: 51.67%
# Loss Pengujian: 0.6816
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 60.71%
# Loss Pelatihan: 0.6594
# Akurasi Pengujian: 59.67%
# Loss Pengujian: 0.6701
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 49.71%
# Loss Pelatihan: 0.6994
# Akurasi Pengujian: 51.00%
# Loss Pengujian: 0.6981
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3252
# Akurasi Pengujian: 83.33%
# Loss Pengujian: 0.3846
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3105
# Akurasi Pengujian: 83.67%
# Loss Pengujian: 0.3734
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3094
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3894
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3278
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3981
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3073
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3801
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3078
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3821
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3076
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3850
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3083
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3893
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3803
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3071
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3805
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3808
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3088
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3836
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 85.29%
# Loss Pelatihan: 0.4073
# Akurasi Pengujian: 82.00%
# Loss Pengujian: 0.4489
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 79.00%
# Loss Pelatihan: 0.5379
# Akurasi Pengujian: 74.33%
# Loss Pengujian: 0.5603
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 71.86%
# Loss Pelatihan: 0.6292
# Akurasi Pengujian: 71.00%
# Loss Pengujian: 0.6349
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 65.14%
# Loss Pelatihan: 0.6634
# Akurasi Pengujian: 59.33%
# Loss Pengujian: 0.6738
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 87.86%
# Loss Pelatihan: 0.3149
# Akurasi Pengujian: 83.33%
# Loss Pengujian: 0.3772
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 76.14%
# Loss Pelatihan: 68.1815
# Akurasi Pengujian: 75.67%
# Loss Pengujian: 71.3180
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3092
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3897
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3097
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3925
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3086
# Akurasi Pengujian: 86.00%
# Loss Pengujian: 0.3739
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3121
# Akurasi Pengujian: 86.33%
# Loss Pengujian: 0.3732
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3073
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3823
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3077
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3833
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3815
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3072
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3782
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3799
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3072
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3824
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3104
# Akurasi Pengujian: 86.00%
# Loss Pengujian: 0.3797
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3494
# Akurasi Pengujian: 81.67%
# Loss Pengujian: 0.3999
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 78.43%
# Loss Pelatihan: 0.5747
# Akurasi Pengujian: 71.67%
# Loss Pengujian: 0.5938
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 65.71%
# Loss Pelatihan: 0.6104
# Akurasi Pengujian: 63.33%
# Loss Pengujian: 0.6127
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3252
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3765
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3091
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3906
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 82.86%
# Loss Pelatihan: 0.7907
# Akurasi Pengujian: 79.67%
# Loss Pengujian: 0.9858
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3092
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3795
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3073
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3782
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3073
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3819
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 88.00%
# Loss Pelatihan: 0.3076
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3861
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3120
# Akurasi Pengujian: 84.00%
# Loss Pengujian: 0.3760
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3822
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3072
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3838
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3824
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3074
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3795
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3069
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3812
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3818
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3100
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3777
#
# Melatih dengan 3 lapisan tersembunyi, 16 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3662
# Akurasi Pengujian: 82.33%
# Loss Pengujian: 0.4108
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3156
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3772
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3100
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3851
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 87.86%
# Loss Pelatihan: 0.3216
# Akurasi Pengujian: 84.00%
# Loss Pengujian: 0.4001
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 83.71%
# Loss Pelatihan: 2.7287
# Akurasi Pengujian: 78.33%
# Loss Pengujian: 3.7184
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3096
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3913
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3098
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3752
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3095
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3811
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3098
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3852
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3074
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3817
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.00%
# Loss Pelatihan: 0.3074
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3797
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3073
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3830
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3101
# Akurasi Pengujian: 86.00%
# Loss Pengujian: 0.3838
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 84.71%
# Loss Pelatihan: 0.4600
# Akurasi Pengujian: 80.33%
# Loss Pengujian: 0.4962
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 81.14%
# Loss Pelatihan: 0.5365
# Akurasi Pengujian: 77.33%
# Loss Pengujian: 0.5523
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 72.29%
# Loss Pelatihan: 0.6322
# Akurasi Pengujian: 70.33%
# Loss Pengujian: 0.6423
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 57.71%
# Loss Pelatihan: 0.6773
# Akurasi Pengujian: 55.67%
# Loss Pengujian: 0.6763
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3136
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3753
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 89.29%
# Loss Pelatihan: 0.3090
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3906
#
# Melatih dengan 3 lapisan tersembunyi, 32 neuron, fungsi aktivasi linear, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3080
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3836
#
# ...
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3073
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3786
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3072
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3802
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3076
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3827
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 87.86%
# Loss Pelatihan: 0.3069
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3809
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3802
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3069
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3816
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Softmax, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3813
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3118
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3869
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 87.14%
# Loss Pelatihan: 6.3977
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 8.5486
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 83.57%
# Loss Pelatihan: 0.6189
# Akurasi Pengujian: 77.67%
# Loss Pengujian: 0.7900
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 83.57%
# Loss Pelatihan: 8.3964
# Akurasi Pengujian: 82.67%
# Loss Pengujian: 11.2049
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3078
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3836
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3102
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3880
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3080
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3797
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3095
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3752
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3082
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3777
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3076
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3796
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3071
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3794
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3096
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3844
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 87.86%
# Loss Pelatihan: 0.3192
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3807
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 87.71%
# Loss Pelatihan: 0.3957
# Akurasi Pengujian: 82.67%
# Loss Pengujian: 0.4439
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 81.71%
# Loss Pelatihan: 0.5085
# Akurasi Pengujian: 75.33%
# Loss Pengujian: 0.5314
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 25 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 82.29%
# Loss Pelatihan: 0.5804
# Akurasi Pengujian: 77.33%
# Loss Pengujian: 0.5889
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3107
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3921
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3079
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3902
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 87.00%
# Loss Pelatihan: 0.3408
# Akurasi Pengujian: 82.33%
# Loss Pengujian: 0.4508
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 86.71%
# Loss Pelatihan: 0.3638
# Akurasi Pengujian: 83.00%
# Loss Pengujian: 0.4680
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3098
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3744
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 89.14%
# Loss Pelatihan: 0.3090
# Akurasi Pengujian: 84.00%
# Loss Pengujian: 0.3951
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3080
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3795
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3105
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3755
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3071
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3812
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3074
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3838
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3071
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3821
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 89.00%
# Loss Pelatihan: 0.3074
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3823
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3071
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3818
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3105
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3781
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 87.14%
# Loss Pelatihan: 0.3666
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.4084
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 50 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 84.29%
# Loss Pelatihan: 0.4851
# Akurasi Pengujian: 79.33%
# Loss Pengujian: 0.5179
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3087
# Akurasi Pengujian: 84.33%
# Loss Pengujian: 0.3756
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 89.29%
# Loss Pelatihan: 0.3104
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3933
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 89.29%
# Loss Pelatihan: 0.3096
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3847
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 89.14%
# Loss Pelatihan: 0.3107
# Akurasi Pengujian: 86.33%
# Loss Pengujian: 0.3922
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 89.14%
# Loss Pelatihan: 0.3327
# Akurasi Pengujian: 86.67%
# Loss Pengujian: 0.3787
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3081
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3827
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 88.00%
# Loss Pelatihan: 0.3083
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3766
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3102
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3720
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.71%
# Loss Pelatihan: 0.3072
# Akurasi Pengujian: 85.67%
# Loss Pengujian: 0.3811
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3074
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3810
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3072
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3851
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3076
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3816
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3069
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3814
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3808
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3076
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3800
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 100 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3318
# Akurasi Pengujian: 86.00%
# Loss Pengujian: 0.3913
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.1, ukuran batch 64
# Akurasi Pelatihan: 87.86%
# Loss Pelatihan: 0.3101
# Akurasi Pengujian: 84.00%
# Loss Pengujian: 0.3767
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.1, ukuran batch 128
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3107
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3974
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.1, ukuran batch 256
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3081
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3824
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.1, ukuran batch 512
# Akurasi Pelatihan: 88.86%
# Loss Pelatihan: 0.3110
# Akurasi Pengujian: 86.00%
# Loss Pengujian: 0.3856
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.01, ukuran batch 64
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3074
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3781
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.01, ukuran batch 128
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3076
# Akurasi Pengujian: 86.33%
# Loss Pengujian: 0.3772
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.01, ukuran batch 256
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3088
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3921
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.01, ukuran batch 512
# Akurasi Pelatihan: 89.00%
# Loss Pelatihan: 0.3103
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3801
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 64
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3822
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 128
# Akurasi Pelatihan: 88.57%
# Loss Pelatihan: 0.3074
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3828
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 256
# Akurasi Pelatihan: 88.00%
# Loss Pelatihan: 0.3071
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3800
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.001, ukuran batch 512
# Akurasi Pelatihan: 88.14%
# Loss Pelatihan: 0.3076
# Akurasi Pengujian: 85.33%
# Loss Pengujian: 0.3818
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 64
# Akurasi Pelatihan: 88.43%
# Loss Pelatihan: 0.3069
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3817
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 128
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 84.67%
# Loss Pengujian: 0.3796
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 256
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3069
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3811
#
# Melatih dengan 3 lapisan tersembunyi, 64 neuron, fungsi aktivasi Tanh, 250 epoch, tingkat pembelajaran 0.0001, ukuran batch 512
# Akurasi Pelatihan: 88.29%
# Loss Pelatihan: 0.3070
# Akurasi Pengujian: 85.00%
# Loss Pengujian: 0.3817

# %%
print("\nBest Hyperparameter Configuration (Overall):")
print(f"Hidden Layers: {best_result['Hyperparameters']['Hidden Layers']}")
print(f"Hidden Neurons: {best_result['Hyperparameters']['Hidden Neurons']}")
print(f"Activation Function: {best_result['Hyperparameters']['Activation Function']}")
print(f"Epochs: {best_result['Hyperparameters']['Epochs']}")
print(f"Learning Rate: {best_result['Hyperparameters']['Learning Rate']}")
print(f"Batch Size: {best_result['Hyperparameters']['Batch Size']}")
print(f"Test Accuracy: {best_result['Test Accuracy'] * 100:.2f}%")
#menampilkan Konfigurasi Hyperparameter Terbaik
# Out:
# Best Hyperparameter Configuration (Overall):
# Hidden Layers: 1
# Hidden Neurons: 4
# Activation Function: Softmax
# Epochs: 25
# Learning Rate: 0.1
# Batch Size: 128
# Test Accuracy: 87.00%

# %%
print("\nWorst Hyperparameter Configuration:")
print(f"Hidden Layers: {worst_result['Hyperparameters']['Hidden Layers']}")
print(f"Hidden Neurons: {worst_result['Hyperparameters']['Hidden Neurons']}")
print(f"Activation Function: {worst_result['Hyperparameters']['Activation Function']}")
print(f"Epochs: {worst_result['Hyperparameters']['Epochs']}")
print(f"Learning Rate: {worst_result['Hyperparameters']['Learning Rate']}")
print(f"Batch Size: {worst_result['Hyperparameters']['Batch Size']}")
print(f"Test Accuracy: {worst_result['Test Accuracy'] * 100:.2f}%")
#menampilkan Konfigurasi Hyperparameter Terburuk
# Out:
# Worst Hyperparameter Configuration:
# Hidden Layers: 3
# Hidden Neurons: 64
# Activation Function: linear
# Epochs: 25
# Learning Rate: 0.1
# Batch Size: 512
# Test Accuracy: 23.67%

# %%
for activation in activation_functions:
    print(f"\nBest Configuration for Activation Function {activation}:")
    if best_per_activation[activation]:
        print(f"Hidden Layers: {best_per_activation[activation]['Hyperparameters']['Hidden Layers']}")
        print(f"Hidden Neurons: {best_per_activation[activation]['Hyperparameters']['Hidden Neurons']}")
        print(f"Activation Function: {activation}")
        print(f"Epochs: {best_per_activation[activation]['Hyperparameters']['Epochs']}")
        print(f"Learning Rate: {best_per_activation[activation]['Hyperparameters']['Learning Rate']}")
        print(f"Batch Size: {best_per_activation[activation]['Hyperparameters']['Batch Size']}")
        print(f"Test Accuracy: {best_per_activation[activation]['Test Accuracy'] * 100:.2f}%")
    else:
        print("No result for this activation function.")
#menampilkan Konfigurasi Terbaik untuk Setiap Fungsi Aktivasi
# Out:
# Best Configuration for Activation Function linear:
# Hidden Layers: 1
# Hidden Neurons: 8
# Activation Function: linear
# Epochs: 50
# Learning Rate: 0.001
# Batch Size: 256
# Test Accuracy: 87.00%
#
# Best Configuration for Activation Function Sigmoid:
# Hidden Layers: 1
# Hidden Neurons: 32
# Activation Function: Sigmoid
# Epochs: 250
# Learning Rate: 0.1
# Batch Size: 256
# Test Accuracy: 87.00%
#
# Best Configuration for Activation Function ReLU:
# Hidden Layers: 1
# Hidden Neurons: 16
# Activation Function: ReLU
# Epochs: 100
# Learning Rate: 0.1
# Batch Size: 512
# Test Accuracy: 87.00%
#
# Best Configuration for Activation Function Softmax:
# Hidden Layers: 1
# Hidden Neurons: 4
# Activation Function: Softmax
# Epochs: 25
# Learning Rate: 0.1
# Batch Size: 128
# Test Accuracy: 87.00%
#
# Best Configuration for Activation Function Tanh:
# Hidden Layers: 1
# Hidden Neurons: 8
# Activation Function: Tanh
# Epochs: 25
# Learning Rate: 0.01
# Batch Size: 64
# Test Accuracy: 86.67%
